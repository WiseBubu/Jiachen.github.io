# %% [markdown]
# # 2019 H1B Visa Petitions Analysis

# %% [markdown]
# # What is H1B Visa?
# ##### In the United States, H1B is one of the Non-immigrant visas. It allows foreign workers to work in the States temporarily in specialty occupations such as IT, medical or business industries. It also requires workers to have a bachelor's or higher degree. Until 2020, more than 580K people are working under H1B in the USA. Upon the current immigration laws, the United States Citizenship and Immigration Services issues 65K H1B visas per year.

# %% [markdown]
# # Contents
#
# - Overview of Top 30 Job Titles With Most Filed H1B Cases
# - Number of IT Job H1B Cases by States
# - Top 10 Sponsors With Most Filed H1B Cases (IT Job ONLY)
# - Number of Top 12 IT Job Employment Comparison : H1B vs National
# - Avg Salary Comparison: H1B vs National
# - H1B Case Status Percentages
# - Deneid H1B Cases
#     - Salary vs Job titles
#     - 5 Numbers Summary: Certified vs Denied
# - Certified Rate vs Avg Salary : Top 10 Sponsors
# - Relationship between Salary and Certified Rate

# %% [markdown]
# # Data Sources
#
# - U.S Department of Labor
#     - https://www.dol.gov/agencies/eta/foreign-labor/performance
# - U.S Bureau of Labor Statistics
#     - https://www.bls.gov/oes/current/oes_nat.htm
#
# You also can find datasets here:
# - https://drive.google.com/drive/folders/1r1N8d-YvC0UdR9HIhhxgHhs7ZBoPzl4C?usp=sharing

# %% [markdown]
# # Challenges of Datasets
# - Datapoints: More than 660K
# - Most of the columns have missing values
# - Non-Normalized Employer Names
# - Each job code matches multiple job titles
# - Wrong information in various columns, such as the data in the column represents the unit of wages
# - Inconsistent States'names (Mixed of Full state name & abbreviation)
# - Inconsistent wages information (Wage units: Year, Month, Week, Bi-Weekly, Hour)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Import packages

# %%
import pandas as pd
import plotly.offline as pyo
import plotly.io as pio
import chart_studio
#import chart_studio.plotly as py
import plotly.express as px
import fnmatch
import numpy as np
import plotly.graph_objects as go
from cleanco import cleanco
from plotly.subplots import make_subplots
import fuzzy_pandas as fpd 
import plotly

# %% [markdown]
# ### Load files

# %%
#py.sign_in('jiachenS', 'DwaaT9qARyVOTnBMYLM4')
chart_studio.tools.set_credentials_file(username='jiachenS', api_key='DwaaT9qARyVOTnBMYLM4')

# %%
#Because file has too many columns, we only load data with needed columns
fields = ['CASE_STATUS','VISA_CLASS','JOB_TITLE', 'SOC_CODE','SOC_TITLE',
         #'TOTAL_WORKER_POSITIONS', 'NEW_EMPLOYMENT','CONTINUED_EMPLOYMENT',
        #  'NEW_CONCURRENT_EMPLOYMENT','CHANGE_EMPLOYER',
          'EMPLOYER_NAME','WORKSITE_STATE_1',
         'PREVAILING_WAGE_1','PW_UNIT_OF_PAY_1','FULL_TIME_POSITION']

# %%
#load file, the data has 260 columns, here we just load columns as needed. 
df = pd.read_csv('H-1B_Disclosure_Data_FY2019.csv',usecols=fields,dtype={'CASE_STATUS':'string',
                                                                         'VISA_CLASS':'string',
                                                                         'JOB_TITLE':'string',
                                                                        # 'TOTAL_WORKER_POISTIONS':int,
                                                                         #'NEW_EMPLOYMENT':'string',
                                                                          #'CONTINUED_EMPLOYMENT':'string',
                                                                         #'NEW_CONCURRENT_EMPLOYMENT':'string',
                                                                         #'CHANGE_EMPLOYER':'string',
                                                                         'SOC_TITLE':'string',
                                                                        'SOC_CODE':'string',
                                                                         'EMPLOYER_NAME':'string',
                                                                         #'WORKSITE_CITY_1':'string',
                                                                         'WORKSITE_STATE_1':'string',
                                                                         "PREVAILING_WAGE_1":float,
                                                                         "PW_UNIT_OF_PAY_1":'string',
                                                                        'FULL_TIME_POSITION':'string'})

# %%
#for this project, we only need data of visa type 'H1B' 
df1=df[(df.VISA_CLASS=='H-1B')]

# %%
#check the first five rows of df1
df1.head()
# Out:
#   CASE_STATUS VISA_CLASS                         JOB_TITLE SOC_CODE  \
# 0   WITHDRAWN       H-1B       ASSOCIATE CREATIVE DIRECTOR    40848
# 5   WITHDRAWN       H-1B           GLOBAL BRAND SUPERVISOR    40848
# 6   WITHDRAWN       H-1B  DIRECTOR OF BUSINESS DEVELOPMENT    40848
# 7   WITHDRAWN       H-1B      HEAD OF BUSINESS DEVELOPMENT    40848
# 8   WITHDRAWN       H-1B    ACCOUNT DIRECTOR, SOCIAL MEDIA    40848
#
#                              SOC_TITLE FULL_TIME_POSITION  \
# 0  ADVERTISING AND PROMOTIONS MANAGERS                  Y
# 5  ADVERTISING AND PROMOTIONS MANAGERS                  Y
# 6  ADVERTISING AND PROMOTIONS MANAGERS                  Y
# 7  ADVERTISING AND PROMOTIONS MANAGERS                  Y
# 8  ADVERTISING AND PROMOTIONS MANAGERS                  Y
#
#                            EMPLOYER_NAME WORKSITE_STATE_1  PREVAILING_WAGE_1  \
# 0                 R/GA MEDIA GROUP, INC.               NY                NaN
# 5        MCCANN-ERICKSON MARKETING, INC.               GA                NaN
# 6                           MH SUB I LLC               CA            97365.0
# 7                             KIIP, INC.       CALIFORNIA           131685.0
# 8  SUNSHINE SACHS & ASSOCIATES WEST, LLC       CALIFORNIA            97365.0
#
#   PW_UNIT_OF_PAY_1
# 0             <NA>
# 5             <NA>
# 6             Year
# 7             Year
# 8             Year

# %% [markdown]
# ### Check Missing Values

# %%
#check missing values in each column 
df1.isnull().sum(axis=0)
# Out:
# CASE_STATUS               0
# VISA_CLASS                0
# JOB_TITLE                 1
# SOC_CODE                  4
# SOC_TITLE                 4
# FULL_TIME_POSITION        0
# EMPLOYER_NAME            10
# WORKSITE_STATE_1         16
# PREVAILING_WAGE_1     32477
# PW_UNIT_OF_PAY_1      32477
# dtype: int64

# %%
#drop rows with missing values in columns 'job title' and 'soc code'
df2 = df1.dropna(subset = ['JOB_TITLE','SOC_CODE'])
#check missing values again 
df2.isnull().sum(axis=0)
# Out:
# CASE_STATUS               0
# VISA_CLASS                0
# JOB_TITLE                 0
# SOC_CODE                  0
# SOC_TITLE                 0
# FULL_TIME_POSITION        0
# EMPLOYER_NAME            10
# WORKSITE_STATE_1         16
# PREVAILING_WAGE_1     32477
# PW_UNIT_OF_PAY_1      32477
# dtype: int64

# %% [markdown]
# ### Create Data Frames

# %%
#create a dataframe for "H1B count by job titles"
#count soc code and get the top 50 soc code 
soc = df2['SOC_CODE'].value_counts()
soc = pd.DataFrame(soc)
soc.reset_index(inplace=True)
soc= soc.rename(columns={'index':'SOC_CODE','SOC_CODE':'COUNT'})
#get top 30 jobs that have most H1B applications
soc30 = soc.nlargest(30,['COUNT'])
soc30.head()
# Out:
#   SOC_CODE   COUNT
# 0  15-1132  215171
# 1  15-1121   72636
# 2  15-1199   63095
# 3  15-1133   31440
# 4  15-1131   17270

# %%
#df2.iloc[:,5:7]
#df2

# %%
#get dataframe for job titles
title = df2.iloc[:,3:5]
title = pd.DataFrame(title)
#drop duplicates
title = title.drop_duplicates()
title.head()
# Out:
#      SOC_CODE                            SOC_TITLE
# 0       40848  ADVERTISING AND PROMOTIONS MANAGERS
# 376     40848             ACCOUNTANTS AND AUDITORS
# 377     44501                   MARKETING MANAGERS
# 382     44501                    MARKETING MANAGER
# 2561    44501         GENERAL & OPERATIONS MANAGER

# %%
#the below code is for the first graph-Top 30 Job titles
#Add job titles to top 30 soc code
H1B_By_Titles = pd.merge(soc30,title,on = 'SOC_CODE',how = 'inner')
#H1B_By_Titles['SOC_CODE'].value_counts()
#a= H1B_By_Titles[H1B_By_Titles['SOC_CODE']=='15-1132']
H1B_By_Titles.drop_duplicates(subset = ['SOC_CODE'],keep = 'first', inplace = True)
H1B_By_Titles
# Out:
#     SOC_CODE   COUNT                                          SOC_TITLE
# 0    15-1132  215171                  SOFTWARE DEVELOPERS, APPLICATIONS
# 37   15-1121   72636                          COMPUTER SYSTEMS ANALYSTS
# 43   15-1199   63095                    COMPUTER OCCUPATIONS, ALL OTHER
# 86   15-1133   31440              SOFTWARE DEVELOPERS, SYSTEMS SOFTWARE
# 101  15-1131   17270                               COMPUTER PROGRAMMERS
# 104  15-2031   11762                       OPERATIONS RESEARCH ANALYSTS
# 107  17-2141   11549                                MECHANICAL ENGINEER
# 114  13-2011   10574                           ACCOUNTANTS AND AUDITORS
# 120  13-1111   10092                                MANAGEMENT ANALYSTS
# 125  15-2041    9541                                      STATISTICIANS
# 134  13-2051    9159                                 FINANCIAL ANALYSTS
# 137  15-1141    9093                            DATABASE ADMINISTRATORS
# 141   409743    9067          COMPUTER AND INFORMATION SYSTEMS MANAGERS
# 148  17-2071    8224                               ELECTRICAL ENGINEERS
# 152  15-1142    7335        NETWORK AND COMPUTER SYSTEMS ADMINISTRATORS
# 156  17-2072    6444             ELECTRONICS ENGINEERS, EXCEPT COMPUTER
# 161  13-1161    5794  MARKET RESEARCH ANALYSTS AND MARKETING SPECIAL...
# 171  19-1042    5574         MEDICAL SCIENTISTS, EXCEPT EPIDEMIOLOGISTS
# 173  29-1069    5425                 PHYSICIANS AND SURGEONS, ALL OTHER
# 181  17-2112    5328                               INDUSTRIAL ENGINEERS
# 183  17-2051    4894                                    CIVIL ENGINEERS
# 186  15-1122    4744                      INFORMATION SECURITY ANALYSTS
# 188  15-1111    4344       COMPUTER AND INFORMATION RESEARCH SCIENTISTS
# 194  17-2199    4172                                VALIDATION ENGINEER
# 209  19-1029    3988                   BIOLOGICAL SCIENTISTS, ALL OTHER
# 221  13-2099    3843                   FINANCIAL SPECIALISTS, ALL OTHER
# 225  19-1021    3305                      BIOCHEMISTS AND BIOPHYSICISTS
# 227  15-1143    3175                        COMPUTER NETWORK ARCHITECTS
# 229  41-9031    2793                                    SALES ENGINEERS
# 232  19-2031    2432                                           CHEMISTS

# %%
#H1B_By_Titles = pd.merge(soc30,title,on = 'SOC_CODE',how = 'inner')

# %%
#the below code is for the graph-IT job map
#get data of IT jobs from the previous dataframe by using filter
IT_code = fnmatch.filter(df2['SOC_CODE'].unique(),'15-*')
#create a new dataframe only contains IT jobs
search_code = '|'.join(IT_code)
df3 = df2[df2['SOC_CODE'].str.contains(search_code)]
#check missing values in df3
#df3.isnull().sum(axis=0)
#drop missing values in df3 
df3 = df3.dropna(subset = ['WORKSITE_STATE_1'])
#check missing values again to make we dropped the correct data
df3.isnull().sum(axis=0)
# Out:
# CASE_STATUS               0
# VISA_CLASS                0
# JOB_TITLE                 0
# SOC_CODE                  0
# SOC_TITLE                 0
# FULL_TIME_POSITION        0
# EMPLOYER_NAME             8
# WORKSITE_STATE_1          0
# PREVAILING_WAGE_1     21063
# PW_UNIT_OF_PAY_1      21063
# dtype: int64

# %%
#check state and city spelling of df3
#state  = df3['WORKSITE_STATE_1'].tolist()
#get the unique values from the list state
#state = set(state)
#state
#US states dictionary
us_state_abbrev = {
    'Alabama': 'AL','Alaska': 'AK','American Samoa': 'AS','Arizona': 'AZ','Arkansas': 'AR',
    'California': 'CA','Colorado': 'CO', 'Connecticut': 'CT','Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA', 'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA',
    'Kansas': 'KS', 'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME','Maryland': 'MD','Massachusetts': 'MA','Michigan': 'MI','Minnesota': 'MN','Mississippi': 'MS',
    'Missouri': 'MO','Montana': 'MT',
    'Nebraska': 'NE','Nevada': 'NV','New Hampshire': 'NH','New Jersey': 'NJ','New Mexico': 'NM',
    'New York': 'NY', 'North Carolina': 'NC', 'North Dakota': 'ND', 'Northern Mariana Islands':'MP',
    'Ohio': 'OH', 'Oklahoma': 'OK','Oregon': 'OR',
    'Pennsylvania': 'PA', 'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',  'South Dakota': 'SD',
    'Tennessee': 'TN',  'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT', 'Virgin Islands': 'VI', 'Virginia': 'VA',
    'Washington': 'WA', 'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY'
}

#covert dict to a dataframe
US_State = pd.DataFrame(list(us_state_abbrev.items()))
US_State = US_State.rename(columns={0:"WORKSITE_STATE_1",1:"Abb"}) 
US_State['WORKSITE_STATE_1'] = US_State['WORKSITE_STATE_1'].str.upper()
US_State.head()
# Out:
#   WORKSITE_STATE_1 Abb
# 0          ALABAMA  AL
# 1           ALASKA  AK
# 2   AMERICAN SAMOA  AS
# 3          ARIZONA  AZ
# 4         ARKANSAS  AR

# %%
#get state name as a new column into dataframe 
df4 = pd.merge(df3,US_State,on='WORKSITE_STATE_1',how='left')
#get state name consistent 
df4['Abb'] = np.where(df4['Abb'].isnull(),df4['WORKSITE_STATE_1'],df4['Abb'])
#drop the orginal column of state 
df4 = df4.drop(['WORKSITE_STATE_1'],axis=1)


df5 = df4.groupby('Abb')['VISA_CLASS'].count().to_frame()
df5.reset_index(inplace=True)
df5.rename(columns={'Abb':'state','VISA_CLASS':'count'},inplace=True)
df5.head()
# Out:
#   state  count
# 0    AK     21
# 1    AL    873
# 2    AR   3704
# 3    AZ   8852
# 4    CA  86519

# %%
#create a dataframe for top 20 companies 
df6 = df2[df2['SOC_CODE'].str.contains(search_code)]
#drop rows with no employer name (8 rows)
df6 = df6.dropna(subset = ['EMPLOYER_NAME'])
#check the missing value for column employer
df6.isnull().sum(axis=0)
# Out:
# CASE_STATUS               0
# VISA_CLASS                0
# JOB_TITLE                 0
# SOC_CODE                  0
# SOC_TITLE                 0
# FULL_TIME_POSITION        0
# EMPLOYER_NAME             0
# WORKSITE_STATE_1          6
# PREVAILING_WAGE_1     21064
# PW_UNIT_OF_PAY_1      21064
# dtype: int64

# %%
#count employer names - find top 10 sponsors with most H1B petitions
count_emp = pd.DataFrame(df6.groupby('EMPLOYER_NAME')['EMPLOYER_NAME'].count())
count_emp.rename(columns={'EMPLOYER_NAME':'H1B_Count'},inplace=True)
count_emp.reset_index(inplace=True)
count_emp.sort_values(by=['H1B_Count'],ascending=False,inplace=True)
#get top 10 H1B sponsors 
count_emp10 = count_emp.nlargest(10,['H1B_Count'])

#remove commas 
count_emp10.EMPLOYER_NAME = count_emp10.EMPLOYER_NAME.str.replace(',','')
#remove dot
count_emp10.EMPLOYER_NAME= count_emp10.EMPLOYER_NAME.str.replace('.','')
#remove text in parenthesis
count_emp10.EMPLOYER_NAME = count_emp10.EMPLOYER_NAME.str.replace(r"\(.*\)","")
#remove spaces
count_emp10.EMPLOYER_NAME= count_emp10.EMPLOYER_NAME.str.strip()
#remove company legal extensions
count_emp10.EMPLOYER_NAME = count_emp10.EMPLOYER_NAME.apply(lambda x: cleanco(x).clean_name() if type(x)==str else x)
#remove country name
c = ['US','AMERICA']
for cc in c:
    count_emp10.EMPLOYER_NAME = count_emp10.EMPLOYER_NAME.apply(lambda x:x.replace(cc,'')
                                                               if (type(x)==str and x.endswith(cc)) else x)
    
count_emp10
# Out:
#                          EMPLOYER_NAME  H1B_Count
# 5902   COGNIZANT TECHNOLOGY SOLUTIONS       27577
# 13242                          INFOSYS      20886
# 25590        TATA CONSULTANCY SERVICES      11772
# 11290                           GOOGLE       7792
# 4636                        CAPGEMINI        7590
# 7590               DELOITTE CONSULTING       6964
# 1498                AMAZONCOM SERVICES       5465
# 413                          ACCENTURE       5294
# 16955                        MICROSOFT       5076
# 12608                              IBM       4866

# %%
#Normalize Employer Names for IT jobs 
#get unique Employer name out of df6
emp_name = df6['EMPLOYER_NAME'].unique()
#convert to a df and assign a name to the column 
emp_name = pd.DataFrame(emp_name)
emp_name.columns = ['Emp_name']
emp_name.head()
# Out:
#                                             Emp_name
# 0                                       NATERA, INC.
# 1  AMERICAN EXPRESS TRAVEL RELATED SERVICES COMPA...
# 2                                         KEYME INC.
# 3          CHOICE HOTELS INTERNATIONAL SERVICES CORP
# 4                            SEI INVESTMENTS COMPANY

# %%
#fuzzy match - looking for similar names for the top 10 companies, and normalized companies' names. 
match = fpd.fuzzy_merge(count_emp10,emp_name,
                       left_on=['EMPLOYER_NAME'],
                       right_on=['Emp_name'],
                       ignore_case = True,
                       keep='match',
                       method='jaro',
                       threshold=0.73)
match
# Out:
#                        EMPLOYER_NAME  \
# 0    COGNIZANT TECHNOLOGY SOLUTIONS
# 1    COGNIZANT TECHNOLOGY SOLUTIONS
# 2    COGNIZANT TECHNOLOGY SOLUTIONS
# 3    COGNIZANT TECHNOLOGY SOLUTIONS
# 4    COGNIZANT TECHNOLOGY SOLUTIONS
# ..                               ...
# 448                              IBM
# 449                              IBM
# 450                              IBM
# 451                              IBM
# 452                              IBM
#
#                                             Emp_name
# 0    COGNIZANT TECHNOLOGY SOLUTIONS U.S. CORPORATION
# 1                          DB GLOBAL TECHNOLOGY INC.
# 2                         CLOUDMINDS TECHNOLOGY INC.
# 3                             CONSOLE TECHNOLOGY INC
# 4             COGNIZANT TECHNOLOGY SOLUTIONS US CORP
# ..                                               ...
# 448                                         IBM CORP
# 449                                        IBM INDIA
# 450                                              IBM
# 451                                   IB SYSTEMS INC
# 452                                  VIBES MEDIA LLC
#
# [453 rows x 2 columns]

# %%
#Normalize sponsors'names
match = pd.DataFrame(match)
match.rename(columns={'EMPLOYER_NAME':'Normalized Name'},inplace=True)
match.head()
# Out:
#                    Normalized Name  \
# 0  COGNIZANT TECHNOLOGY SOLUTIONS
# 1  COGNIZANT TECHNOLOGY SOLUTIONS
# 2  COGNIZANT TECHNOLOGY SOLUTIONS
# 3  COGNIZANT TECHNOLOGY SOLUTIONS
# 4  COGNIZANT TECHNOLOGY SOLUTIONS
#
#                                           Emp_name
# 0  COGNIZANT TECHNOLOGY SOLUTIONS U.S. CORPORATION
# 1                        DB GLOBAL TECHNOLOGY INC.
# 2                       CLOUDMINDS TECHNOLOGY INC.
# 3                           CONSOLE TECHNOLOGY INC
# 4           COGNIZANT TECHNOLOGY SOLUTIONS US CORP

# %%
#create a new dataframe

Amazon = fnmatch.filter(match[match['Normalized Name'] == 'AMAZONCOM SERVICES']['Emp_name'],'AMAZON*')
Accenture = match[match['Normalized Name'] == 'ACCENTURE'].iloc[0,:].tolist()
CTS = match[match['Normalized Name'] == 'COGNIZANT TECHNOLOGY SOLUTIONS '].iloc[0,:].tolist()
CTS1 = match[match['Normalized Name'] == 'COGNIZANT TECHNOLOGY SOLUTIONS '].iloc[4,:].tolist()
Deloitte = fnmatch.filter(match[match['Normalized Name'] == 'DELOITTE CONSULTING']['Emp_name'],'DELOITTE*')
GOOGLE = fnmatch.filter(match[match['Normalized Name'] == 'GOOGLE']['Emp_name'],'GOOGLE*')
INFOSYS = match[match['Normalized Name'] == 'INFOSYS'].iloc[4,:].tolist()
TATA = match[match['Normalized Name'] == 'TATA CONSULTANCY SERVICES'].iloc[6,:].tolist()
CAPGEMINI = fnmatch.filter(match[match['Normalized Name'] == 'CAPGEMINI ']['Emp_name'],'CAPGEMINI*')
MICROSOFT = fnmatch.filter(match[match['Normalized Name'] == 'MICROSOFT']['Emp_name'],'MICROSOFT*')
IBM = fnmatch.filter(match[match['Normalized Name'] == 'IBM']['Emp_name'],'IBM*')
TOP10 = Amazon+Accenture+CTS+CTS1+Deloitte+GOOGLE+INFOSYS+TATA+CAPGEMINI+MICROSOFT+IBM
TOP10 = pd.DataFrame(TOP10)

TOP10.rename(columns={0:'EMPLOYER_NAME'},inplace=True)
TOP10['Normalized_Name'] = 'AMAZON'
TOP10.iloc[25:27,1] = 'ACCENTURE'
TOP10.iloc[27:31,1] ='COGNIZANT'
TOP10.iloc[31:38,1] ='DELOITTE'
TOP10.iloc[38:46,1] ='GOOGLE'
TOP10.iloc[46:48,1] ='INFOSYS'
TOP10.iloc[48:50,1]='TATA'
TOP10.iloc[50:57,1] ='CAPGEMINI'
TOP10.iloc[57:60,1]='MICROSOFT '
TOP10.iloc[60:,1]='IBM'
TOP10.head()
# Out:
#                 EMPLOYER_NAME Normalized_Name
# 0   AMAZON.COM SERVICES, INC.          AMAZON
# 1   AMAZON WEB SERVICES, INC.          AMAZON
# 2         AMAZON ROBOTICS LLC          AMAZON
# 3    AMAZON.COM SERVICES, INC          AMAZON
# 4  AMAZON.COM  SERVICES, INC.          AMAZON

# %%
#get number of petitions for top 10 sponsors
#df6 contains IT jobs data only
r = df6.merge(TOP10,on=['EMPLOYER_NAME'],how='inner')
emp_count = pd.DataFrame(r.groupby('Normalized_Name')['EMPLOYER_NAME'].count())
emp_count.reset_index(inplace=True)
emp_count.rename(columns={'EMPLOYER_NAME':'Num of H1B Petitions'},inplace=True)
emp_count
# Out:
#   Normalized_Name  Num of H1B Petitions
# 0       ACCENTURE                  5295
# 1          AMAZON                  7153
# 2       CAPGEMINI                  8189
# 3       COGNIZANT                 27626
# 4        DELOITTE                  7699
# 5          GOOGLE                  8302
# 6             IBM                  4878
# 7         INFOSYS                 20886
# 8      MICROSOFT                   5078
# 9            TATA                 11772

# %%
#calculate previling wages 
df8 = df2[df2['SOC_CODE'].str.contains(search_code)]
df8 = df8.dropna(subset = ['PREVAILING_WAGE_1','PW_UNIT_OF_PAY_1'])
df8.isnull().sum(axis=0)
# Out:
# CASE_STATUS           0
# VISA_CLASS            0
# JOB_TITLE             0
# SOC_CODE              0
# SOC_TITLE             0
# FULL_TIME_POSITION    0
# EMPLOYER_NAME         5
# WORKSITE_STATE_1      2
# PREVAILING_WAGE_1     0
# PW_UNIT_OF_PAY_1      0
# dtype: int64

# %%
#Salary comparison for top IT jobs out of 30 titles (12 titles)
Top_IT_Title = fnmatch.filter(H1B_By_Titles['SOC_CODE'].unique(),'15-*')
df9 = df8[df8['SOC_CODE'].isin(Top_IT_Title)]
#update col 'PW_UNIT_PAY_1' with data Hour and wages greater than 1000
df9 = df9.copy()
df9.loc[(df9.PREVAILING_WAGE_1 > 1000) & (df9.PW_UNIT_OF_PAY_1 == 'Hour'),'PW_UNIT_OF_PAY_1']='Year'
df9.loc[(df9.PREVAILING_WAGE_1 > 10000) & (df9.PW_UNIT_OF_PAY_1 == 'Month'),'PW_UNIT_OF_PAY_1']='Year'

# %%
#calculate year salary
W = df9[df9['PW_UNIT_OF_PAY_1'] == 'Week']
S = (W['SOC_CODE'], W['SOC_TITLE'],W['CASE_STATUS'],W['EMPLOYER_NAME'],W['PREVAILING_WAGE_1']*48,W['FULL_TIME_POSITION'])
result_Week = pd.DataFrame(list(S))
s_Week = result_Week.T

W = df9[df9['PW_UNIT_OF_PAY_1'] == 'Month']
S = (W['SOC_CODE'],W['SOC_TITLE'],W['CASE_STATUS'],W['EMPLOYER_NAME'],W['PREVAILING_WAGE_1']*12,W['FULL_TIME_POSITION'])
result_Month = pd.DataFrame(list(S))
s_Month = result_Month.T

W = df9[df9['PW_UNIT_OF_PAY_1'] == 'Bi-Weekly']
S = (W['SOC_CODE'],W['SOC_TITLE'],W['CASE_STATUS'],W['EMPLOYER_NAME'],W['PREVAILING_WAGE_1']*96,W['FULL_TIME_POSITION'])
result_Biweekly = pd.DataFrame(list(S))
s_Biiweekly = result_Biweekly.T 

Hour = df9[df9['PW_UNIT_OF_PAY_1'] == 'Hour']
S = (W['SOC_CODE'],Hour['SOC_TITLE'],Hour['CASE_STATUS'],Hour['EMPLOYER_NAME'],Hour['PREVAILING_WAGE_1']*1920,W['FULL_TIME_POSITION'])
result_Hour = pd.DataFrame(list(S))
s_Hour = result_Hour.T

W = df9[df9['PW_UNIT_OF_PAY_1'] == 'Year']
s_Year = W[['SOC_CODE','SOC_TITLE','CASE_STATUS','EMPLOYER_NAME','PREVAILING_WAGE_1','FULL_TIME_POSITION']]

# %%
#combine above data frames -- Year salary for each poistion and employer
frames = [s_Week,s_Month,s_Hour,s_Year]
Year_Salary = pd.concat(frames)
Year_Salary[Year_Salary['CASE_STATUS'] == 'DENIED']
# Out:
#        SOC_CODE                          SOC_TITLE CASE_STATUS  \
# 343967  15-1132  SOFTWARE DEVELOPERS, APPLICATIONS      DENIED
# 169246  15-1131               COMPUTER PROGRAMMERS      DENIED
# 170886  15-1131               COMPUTER PROGRAMMERS      DENIED
# 480149  15-1199    COMPUTER OCCUPATIONS, ALL OTHER      DENIED
# 93479       NaN          COMPUTER SYSTEMS ANALYSTS      DENIED
# ...         ...                                ...         ...
# 534691  15-2041                      STATISTICIANS      DENIED
# 535073  15-2041                      STATISTICIANS      DENIED
# 535141  15-2041                      STATISTICIANS      DENIED
# 535719  15-2041                      STATISTICIANS      DENIED
# 536211  15-2041                      STATISTICIANS      DENIED
#
#                                             EMPLOYER_NAME PREVAILING_WAGE_1  \
# 343967                                ALL TO SUCCESS INC.             94512
# 169246                                           YITU INC            101424
# 170886  ADMINISTRATIVE OFFICE OF THE COURTS;TN SUPREME...             67656
# 480149  ADMINISTRATIVE OFFICE OF THE COURTS;TN SUPREME...             66000
# 93479                                        XCELTECH INC           72902.4
# ...                                                   ...               ...
# 534691                                    ABS GLOBAL, INC             74901
# 535073                 NEUSTAR INFORMATION SERVICES, INC.             89918
# 535141                 NEUSTAR INFORMATION SERVICES, INC.             89918
# 535719                                       KABBAGE INC.             97906
# 536211                                EXLSERVICE.COM, LLC             85083
#
#        FULL_TIME_POSITION
# 343967                  Y
# 169246                  Y
# 170886                  Y
# 480149                  Y
# 93479                 NaN
# ...                   ...
# 534691                  Y
# 535073                  Y
# 535141                  Y
# 535719                  Y
# 536211                  Y
#
# [2371 rows x 6 columns]

# %%
#for each position, calculate the avg salary 
Year_Salary[['PREVAILING_WAGE_1']] = Year_Salary[['PREVAILING_WAGE_1']].apply(pd.to_numeric)
Avg = Year_Salary.groupby('SOC_CODE')['PREVAILING_WAGE_1'].mean()
Avg = pd.DataFrame(Avg)
Avg.reset_index(inplace=True)
Avg.columns=['SOC_CODE','H1B_AVG_SALARY']
#tech_title = (pd.DataFrame(Year_Salary.iloc[:,0:2])).drop_duplicates(subset = ['SOC_CODE'],keep = 'first', inplace = True)
#Avg = pd.merge(Avg, tech_title, how='left', on ='SOC_CODE')
Avg['H1B_Title'] = ['COMPUTER AND INFORMATION RESEARCH SCIENTISTS',
                   'COMPUTER SYSTEMS ANALYSTS',
                   'INFORMATION SECURITY ANALYSTS',
                   'COMPUTER PROGRAMMERS',
                   'SOFTWARE DEVELOPERS, APPLICATIONS',
                   'SOFTWARE DEVELOPERS, SYSTEMS SOFTWARE',
                   'DATABASE ADMINISTRATORS',
                   'NETWORK AND COMPUTER SYSTEMS ADMINISTRATORS',
                   'COMPUTER NETWORK ARCHITECTS',
                   'COMPUTER OCCUPATIONS, ALL OTHER',
                   'OPERATIONS RESEARCH ANALYSTS',
                   'STATISTICIANS']

Avg.head()
# Out:
#   SOC_CODE  H1B_AVG_SALARY                                     H1B_Title
# 0  15-1111   112769.413140  COMPUTER AND INFORMATION RESEARCH SCIENTISTS
# 1  15-1121    85730.649175                     COMPUTER SYSTEMS ANALYSTS
# 2  15-1122    92045.179703                 INFORMATION SECURITY ANALYSTS
# 3  15-1131    74083.980762                          COMPUTER PROGRAMMERS
# 4  15-1132    97035.008865             SOFTWARE DEVELOPERS, APPLICATIONS

# %%
#import national avg salary data for above poisitons
National = pd.read_excel('2019 National IT Occupation Data.xlsx')
National['Occupation title']= National['Occupation title'].str.upper()
salary_comparison = Avg.merge(National.iloc[:,1:9] ,left_on='H1B_Title',right_on='Occupation title')
salary_comparison.head()
# Out:
#   SOC_CODE  H1B_AVG_SALARY                                     H1B_Title  \
# 0  15-1111   112769.413140  COMPUTER AND INFORMATION RESEARCH SCIENTISTS
# 1  15-1121    85730.649175                     COMPUTER SYSTEMS ANALYSTS
# 2  15-1122    92045.179703                 INFORMATION SECURITY ANALYSTS
# 3  15-1131    74083.980762                          COMPUTER PROGRAMMERS
# 4  15-1132    97035.008865             SOFTWARE DEVELOPERS, APPLICATIONS
#
#                                Occupation title   Level  Employment  \
# 0  COMPUTER AND INFORMATION RESEARCH SCIENTISTS  detail       30780
# 1                     COMPUTER SYSTEMS ANALYSTS  detail      589060
# 2                 INFORMATION SECURITY ANALYSTS  detail      125570
# 3                          COMPUTER PROGRAMMERS  detail      199540
# 4             SOFTWARE DEVELOPERS, APPLICATIONS   broad     1754750
#
#    Employment RSE  Employment per 1,000 jobs  Median hourly wage  \
# 0           0.036                      0.210               59.06
# 1           0.010                      4.011               43.71
# 2           0.018                      0.855               47.95
# 3           0.016                      1.359               41.61
# 4           0.007                     11.947               49.20
#
#    Mean hourly wage  Annual mean wage
# 0             61.28            127460
# 1             46.23             96160
# 2             50.10            104210
# 3             44.53             92610
# 4             51.44            106980

# %%
#get the total number of H1B peptitions for each poistions 
df11 = H1B_By_Titles[H1B_By_Titles['SOC_CODE'].isin(Top_IT_Title)]
Num_Emp_comparison = df11.merge(National.iloc[:,1:4], left_on='SOC_TITLE',right_on='Occupation title')
Num_Emp_comparison.rename({'COUNT':'Total H1B Employment','Employment':'Total National Employment'},axis=1,inplace=True)
#add percentage 

#total num of IT job employment in the United States in 2019
National_Total_Emp = Num_Emp_comparison['Total National Employment'].sum()
Num_Emp_comparison['Total'] = National_Total_Emp

# %%
NonH1B = Num_Emp_comparison.iloc[:,1:6]
NonH1B['Num_NonH1B'] = (NonH1B['Total National Employment']-NonH1B['Total H1B Employment'])
NonH1B=NonH1B.drop(['Total H1B Employment','Total National Employment'],axis=1)
NonH1B=NonH1B[['Num_NonH1B','SOC_TITLE','Occupation title','Level']]
NonH1B['Employment 2'] ='NonH1B'
NonH1B.rename(columns={'Num_NonH1B':'Num'},inplace=True)

a = Num_Emp_comparison.iloc[:,1:5]
a['Employment level 3'] = 'H1B'
a.rename(columns={'Total H1B Employment':'Num'},inplace=True)

frames = [a,NonH1B]
treemap = pd.concat(frames)
treemap.fillna('NonH1B',inplace=True)
treemap['Employment level1']='National'
treemap['Total']=National_Total_Emp

# %%
#dataframe for case status for pie chart
df12 = df2[df2['SOC_CODE'].str.contains(search_code)]
count_case_status = df12.groupby('CASE_STATUS')['CASE_STATUS'].count()
count_case_status = pd.DataFrame(count_case_status)
count_case_status.rename(columns={'CASE_STATUS':'Count'},inplace=True)
count_case_status.reset_index(inplace=True)
count_case_status['Total'] = count_case_status['Count'].sum()
Percentage = pd.DataFrame((count_case_status['Count']/count_case_status['Total']).mul(100).round(0).astype(str)+'%')
Percentage = Percentage.rename(columns={0:'P'})
IT_Case_Status = pd.concat([count_case_status,Percentage],axis=1)

# %%
#Rejection rate between NonIT and IT jobs
#df2 - df12 = NonIT jobs
df13 = df2[~df2.index.isin(df12.index)]
count_case_status_NonIT = df13.groupby('CASE_STATUS')['CASE_STATUS'].count()
count_case_status_NonIT = pd.DataFrame(count_case_status_NonIT)
count_case_status_NonIT.rename(columns={'CASE_STATUS':'NonIT_Count'},inplace=True)
count_case_status_NonIT.reset_index(inplace=True)
status = pd.concat([IT_Case_Status,count_case_status_NonIT],axis=1)
status = status.drop(['P'],axis=1)
status['sum'] = status['Count'] + status['NonIT_Count']
status =status.iloc[2,:]
denied = status.T
denied['p_it'] = round(denied['Count']/denied['sum']*100,0)
denied['p_nonit'] = round(denied['NonIT_Count']/denied['sum']*100,0)
denied = (pd.DataFrame(denied))
denied = denied.T

# %%
#deney factors (salary,Job titles)
deny= Year_Salary[Year_Salary['CASE_STATUS'] == 'DENIED']

deny = deny.copy()
deny.loc[(deny.SOC_TITLE == 'COMPUTER SYSTEMS ANALYSTS') ,'SOC_TITLE']='COMPUTER SYSTEMS ANALYST'
deny.loc[(deny.SOC_TITLE == 'SOFTWARE DEVELOPERS, APPLICATIONS') ,'SOC_TITLE']='SOFTWARE DEVELOPER, APPLICATIONS'

# %%
#5 Numbers comparison between denied and certified H1B of TOP 12 IT jobs
#Year_Salary.head()
#count of certified case for each salary 
C = Year_Salary[(Year_Salary['CASE_STATUS']=='CERTIFIED') & (Year_Salary['FULL_TIME_POSITION']=='Y')]
              
C_COUNT = pd.DataFrame(C.groupby('PREVAILING_WAGE_1')['CASE_STATUS'].count())
C_COUNT.reset_index(inplace=True)
C_COUNT.rename(columns={'CASE_STATUS':'COUNT'},inplace=True)
C_COUNT['STATUS'] ='CERTIFIED'

#count of denied case for each salary 
D = Year_Salary[(Year_Salary['CASE_STATUS']=='DENIED') & (Year_Salary['FULL_TIME_POSITION']=='Y')]
D_COUNT = pd.DataFrame(D.groupby('PREVAILING_WAGE_1')['CASE_STATUS'].count())
D_COUNT.reset_index(inplace=True)
D_COUNT.rename(columns={'CASE_STATUS':'COUNT'},inplace=True)
D_COUNT['STATUS'] ='DENIED'
#D_COUNT

F = [C_COUNT,D_COUNT]
Box = pd.concat(F)

Box.head()
# Out:
#    PREVAILING_WAGE_1  COUNT     STATUS
# 0            17410.0      3  CERTIFIED
# 1            18699.0      4  CERTIFIED
# 2            19594.0      2  CERTIFIED
# 3            23941.0      1  CERTIFIED
# 4            24128.0      1  CERTIFIED

# %%
#the following code for IT jobs only
#get total filed H1b
last = Year_Salary.merge(TOP10,on=['EMPLOYER_NAME'],how='inner')
last_filed = pd.DataFrame(last.groupby('Normalized_Name')['CASE_STATUS'].count())
last_filed.reset_index(inplace=True)
last_filed.columns=['Normalized_Name','Total Filed H1B']
#last_filed

#get total certified cases
final = last[last['CASE_STATUS']=='CERTIFIED']
last_pass = pd.DataFrame(final.groupby('Normalized_Name')['CASE_STATUS'].count())
last_pass.reset_index(inplace=True)
last_pass.columns=['Normalized_Name','Total Certified H1B']
#last_pass

#get certified rate
#merge above two dfs first
combined = last_filed.merge(last_pass,on=['Normalized_Name'],how='inner')
combined['Certified_Rate'] = round(combined['Total Certified H1B'] / combined['Total Filed H1B'] *100 ,2)
#combined

#get the salary mean
wage = pd.DataFrame(round(final.groupby('Normalized_Name')['PREVAILING_WAGE_1'].mean(),2))
wage.reset_index(inplace=True)
wage.columns=['Normalized_Name','Avg Salary']
combined1 = combined.merge(wage,on=['Normalized_Name'],how='inner')
combined1
# Out:
#   Normalized_Name  Total Filed H1B  Total Certified H1B  Certified_Rate  \
# 0       ACCENTURE             5228                 5119           97.92
# 1          AMAZON             7065                 6939           98.22
# 2       CAPGEMINI             8131                 8004           98.44
# 3       COGNIZANT            27181                26898           98.96
# 4        DELOITTE             7478                 7369           98.54
# 5          GOOGLE             7522                 7167           95.28
# 6             IBM             4680                 3964           84.70
# 7         INFOSYS            20767                20754           99.94
# 8      MICROSOFT              4975                 4975          100.00
# 9            TATA            10082                10058           99.76
#
#    Avg Salary
# 0    87719.23
# 1    99304.57
# 2    86421.20
# 3    86142.18
# 4    85183.25
# 5   115424.03
# 6    89259.83
# 7    80728.88
# 8   114618.13
# 9    72351.87

# %%
d = pd.DataFrame(final.groupby('PREVAILING_WAGE_1')['CASE_STATUS'].count())
d.reset_index(inplace=True)
d.columns=['Salary','Count of Ceritified Cases']
d
# Out:
#         Salary  Count of Ceritified Cases
# 0      18699.0                          4
# 1      19594.0                          2
# 2      24544.0                          1
# 3      25542.0                          1
# 4      32766.0                          1
# ...        ...                        ...
# 3018  176072.0                          1
# 3019  179150.0                          1
# 3020  180294.0                          1
# 3021  184350.0                          3
# 3022  201094.0                          1
#
# [3023 rows x 2 columns]

# %% [markdown]
# # Visualization

# %% [markdown]
# ### Number of Petitions - Top 30 Job Titles

# %%
#pyo.offline.init_notebook_mode(connected=True)
fig = px.bar(H1B_By_Titles, x = 'SOC_TITLE', y = 'COUNT',
            hover_data = ['SOC_TITLE','COUNT'],
            labels  = {'SOC_TITLE':'Job Titles'})
fig.update_layout(xaxis_tickangle=-45,
                 width = 1000, height=700,
                 title_text = 'Top 30 Jobs with H1B petitions in 2019')
#fig.show()
#py.iplot(fig, filename='Top30Jobs')
pyo.offline.plot(fig,filename='Top30Jobs')
#pio.write_html(fig,file='Top30JOBS.htlml',auto_open=False)
# Out:
# 'Top30Jobs.html'

# %% [markdown]
# ### H1B IT Job Locations

# %%
fig = go.Figure(data = go.Choropleth(locations=df5['state'],
                                   z = df5['count'] , 
              locationmode = 'USA-states',
               colorscale = 'Reds',             
               colorbar_title = 'Number of H1B petitions'))
fig.update_layout(geo_scope = 'usa',
                 title_text = 'Number of H1B petitions of IT jobs by states ')
fig.show()
# Out:
# <div>                            <div id="5c8dfd73-2ab4-4031-a6ea-f2e15ce323ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c8dfd73-2ab4-4031-a6ea-f2e15ce323ad")) {                    Plotly.newPlot(                        "5c8dfd73-2ab4-4031-a6ea-f2e15ce323ad",                        [{"colorbar": {"title": {"text": "Number of H1B petitions"}}, "colorscale": [[0.0, "rgb(255,245,240)"], [0.125, "rgb(254,224,210)"], [0.25, "rgb(252,187,161)"], [0.375, "rgb(252,146,114)"], [0.5, "rgb(251,106,74)"], [0.625, "rgb(239,59,44)"], [0.75, "rgb(203,24,29)"], [0.875, "rgb(165,15,21)"], [1.0, "rgb(103,0,13)"]], "locationmode": "USA-states", "locations": ["AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "GA", "GU", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MARSHALL ISLANDS", "MD", "ME", "MI", "MN", "MO", "MP", "MS", "MT", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "PALAU", "PR", "PW", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VI", "VT", "WA", "WI", "WV", "WY"], "type": "choropleth", "z": [21, 873, 3704, 8852, 86519, 5397, 7755, 2482, 2687, 15858, 17948, 3, 171, 2227, 343, 23842, 4435, 1744, 2069, 882, 15944, 1, 7249, 290, 12108, 8073, 7339, 5, 285, 76, 17343, 155, 1753, 1308, 30759, 352, 925, 25981, 12458, 920, 3536, 16502, 1, 44, 1, 2077, 2007, 94, 5244, 49163, 2468, 14970, 2, 166, 23154, 4937, 151, 37]}],                        {"geo": {"scope": "usa"}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777 ...

# %% [markdown]
# ### Top 10 H1B Sponsors

# %%
fig = px.bar(emp_count,x='Num of H1B Petitions',y='Normalized_Name',
          orientation='h' ,color='Normalized_Name' )
fig.update_layout(title_text='Top 10 Companies filed most H1B petitions in 2019',showlegend=False)
fig.show()
# Out:
# <div>                            <div id="cc6b8fe2-ca40-481e-babd-299220380e0b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc6b8fe2-ca40-481e-babd-299220380e0b")) {                    Plotly.newPlot(                        "cc6b8fe2-ca40-481e-babd-299220380e0b",                        [{"alignmentgroup": "True", "hovertemplate": "Normalized_Name=%{y}<br>Num of H1B Petitions=%{x}<extra></extra>", "legendgroup": "ACCENTURE", "marker": {"color": "#636efa"}, "name": "ACCENTURE", "offsetgroup": "ACCENTURE", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [5295], "xaxis": "x", "y": ["ACCENTURE"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Normalized_Name=%{y}<br>Num of H1B Petitions=%{x}<extra></extra>", "legendgroup": "AMAZON", "marker": {"color": "#EF553B"}, "name": "AMAZON", "offsetgroup": "AMAZON", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [7153], "xaxis": "x", "y": ["AMAZON"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Normalized_Name=%{y}<br>Num of H1B Petitions=%{x}<extra></extra>", "legendgroup": "CAPGEMINI", "marker": {"color": "#00cc96"}, "name": "CAPGEMINI", "offsetgroup": "CAPGEMINI", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [8189], "xaxis": "x", "y": ["CAPGEMINI"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Normalized_Name=%{y}<br>Num of H1B Petitions=%{x}<extra></extra>", "legendgroup": "COGNIZANT", "marker": {"color": "#ab63fa"}, "name": "COGNIZANT", "offsetgroup": "COGNIZANT", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [27626], "xaxis": "x", "y": ["COGNIZANT"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Normalized_Name=%{y}<br>Num of H1B Petitions=%{x}<extra></extra>", "legendgroup": "DELOITTE", "marker": {"color": "#FFA15A"}, "name": "DELOITTE", "offsetgroup": "DELOITTE", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [7699], "xaxis": "x", "y": ["DELOITTE"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Normalized_Name=%{y}<br>Num of H1B Petitions=%{x}<extra></extra>", "legendgroup": "GOOGLE", "marker": {"color": "#19d3f3"}, "name": "GOOGLE", "offsetgroup": "GOOGLE", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [8302], "xaxis": "x", "y": ["GOOGLE"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Normalized_Name=%{y}<br>Num of H1B Petitions=%{x}<extra></extra>", "legendgroup": "IBM", "marker": {"color": "#FF6692"}, "name": "IBM", "offsetgroup": "IBM", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [4878], "xaxis": "x", "y": ["IBM"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Normalized_Name=%{y}<br>Num of H1B Petitions=%{x}<extra></extra>", "legendgroup": "INFOSYS", "marker": {"color": "#B6E880"}, "name": "INFOSYS", "offsetgroup": "INFOSYS", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [20886], "xaxis": "x", "y": ["INFOSYS"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Normalized_Name=%{y}<br>Num of H1B Petitions=%{x}<extra></extra>", "legendgroup": "MICROSOFT ", "marker": {"color": "#FF97FF"}, "name": "MICROSOFT ", "offsetgroup": "MICROSOFT ", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [5078], "xaxis": "x", "y": ["MICROSOFT "], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Normalized_Name=%{y}<br>Num of H1B Petitions=%{x}<extra></extra>", "legendgroup": "TATA", "marker": {"color": "#FECB52"}, "name": "TATA", "offsetgroup": "TATA", "orientation": "h", "showlegend": true, "textposition": "au ...

# %% [markdown]
# ### Number of employment of H1B vs Nationals by Top 12 IT Positions

# %%
fig = px.treemap(treemap, path=['Total','Occupation title','Employment level1','Employment level 3']
                , values = 'Num')
fig.update_layout(title_text='H1B vs Nationals in Number of Employment In 2019')
fig.show()
# Out:
# <div>                            <div id="c23b9afc-52cb-48fd-92fb-d4236314b26e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c23b9afc-52cb-48fd-92fb-d4236314b26e")) {                    Plotly.newPlot(                        "c23b9afc-52cb-48fd-92fb-d4236314b26e",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>Num=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["5270830/COMPUTER AND INFORMATION RESEARCH SCIENTISTS/National/H1B", "5270830/COMPUTER NETWORK ARCHITECTS/National/H1B", "5270830/COMPUTER OCCUPATIONS, ALL OTHER/National/H1B", "5270830/COMPUTER PROGRAMMERS/National/H1B", "5270830/COMPUTER SYSTEMS ANALYSTS/National/H1B", "5270830/DATABASE ADMINISTRATORS/National/H1B", "5270830/INFORMATION SECURITY ANALYSTS/National/H1B", "5270830/NETWORK AND COMPUTER SYSTEMS ADMINISTRATORS/National/H1B", "5270830/OPERATIONS RESEARCH ANALYSTS/National/H1B", "5270830/SOFTWARE DEVELOPERS, APPLICATIONS/National/H1B", "5270830/SOFTWARE DEVELOPERS, SYSTEMS SOFTWARE/National/H1B", "5270830/STATISTICIANS/National/H1B", "5270830/COMPUTER AND INFORMATION RESEARCH SCIENTISTS/National/NonH1B", "5270830/COMPUTER NETWORK ARCHITECTS/National/NonH1B", "5270830/COMPUTER OCCUPATIONS, ALL OTHER/National/NonH1B", "5270830/COMPUTER PROGRAMMERS/National/NonH1B", "5270830/COMPUTER SYSTEMS ANALYSTS/National/NonH1B", "5270830/DATABASE ADMINISTRATORS/National/NonH1B", "5270830/INFORMATION SECURITY ANALYSTS/National/NonH1B", "5270830/NETWORK AND COMPUTER SYSTEMS ADMINISTRATORS/National/NonH1B", "5270830/OPERATIONS RESEARCH ANALYSTS/National/NonH1B", "5270830/SOFTWARE DEVELOPERS, APPLICATIONS/National/NonH1B", "5270830/SOFTWARE DEVELOPERS, SYSTEMS SOFTWARE/National/NonH1B", "5270830/STATISTICIANS/National/NonH1B", "5270830/COMPUTER AND INFORMATION RESEARCH SCIENTISTS/National", "5270830/COMPUTER NETWORK ARCHITECTS/National", "5270830/COMPUTER OCCUPATIONS, ALL OTHER/National", "5270830/COMPUTER PROGRAMMERS/National", "5270830/COMPUTER SYSTEMS ANALYSTS/National", "5270830/DATABASE ADMINISTRATORS/National", "5270830/INFORMATION SECURITY ANALYSTS/National", "5270830/NETWORK AND COMPUTER SYSTEMS ADMINISTRATORS/National", "5270830/OPERATIONS RESEARCH ANALYSTS/National", "5270830/SOFTWARE DEVELOPERS, APPLICATIONS/National", "5270830/SOFTWARE DEVELOPERS, SYSTEMS SOFTWARE/National", "5270830/STATISTICIANS/National", "5270830/COMPUTER AND INFORMATION RESEARCH SCIENTISTS", "5270830/COMPUTER NETWORK ARCHITECTS", "5270830/COMPUTER OCCUPATIONS, ALL OTHER", "5270830/COMPUTER PROGRAMMERS", "5270830/COMPUTER SYSTEMS ANALYSTS", "5270830/DATABASE ADMINISTRATORS", "5270830/INFORMATION SECURITY ANALYSTS", "5270830/NETWORK AND COMPUTER SYSTEMS ADMINISTRATORS", "5270830/OPERATIONS RESEARCH ANALYSTS", "5270830/SOFTWARE DEVELOPERS, APPLICATIONS", "5270830/SOFTWARE DEVELOPERS, SYSTEMS SOFTWARE", "5270830/STATISTICIANS", "5270830"], "labels": ["H1B", "H1B", "H1B", "H1B", "H1B", "H1B", "H1B", "H1B", "H1B", "H1B", "H1B", "H1B", "NonH1B", "NonH1B", "NonH1B", "NonH1B", "NonH1B", "NonH1B", "NonH1B", "NonH1B", "NonH1B", "NonH1B", "NonH1B", "NonH1B", "National", "National", "National", "National", "National", "National", "National", "National", "National", "National", "National", "National", "COMPUTER AND INFORMATION RESEARCH SCIENTISTS", "COMPUTER NETWORK ARCHITECTS", "COMPUTER OCCUPATIONS, ALL OTHER", "COMPUTER PROGRAMMERS", "COMPUTER SYSTEMS ANALYSTS", "DATABASE ADMINISTRATORS", "INFORMATION SECURITY ANALYSTS", "NETWORK AND COMPUTER SYSTEMS ADMINISTRATORS", "OPERATIONS RESEARCH ANALYSTS", "SOFTWARE DEVELOPERS, APPLICATIONS", "SOFTWARE DEVELOPERS, SYSTEMS SOFTWARE", "STATISTICIANS", "5270830"], "name": "", "parents": ["5270830/COMPUTER AND INFORMATION RESE ...

# %% [markdown]
# ### Top 12 IT jobs Avg Salary between H1B and National

# %%
job = salary_comparison['H1B_Title']
fig = go.Figure(data=[
    go.Bar(name='H1B Avg Salary',x=job,y=salary_comparison['H1B_AVG_SALARY']),
    go.Bar(name='National Avg Salary',x=job, y=salary_comparison['Annual mean wage'])
    ])

fig.update_layout(title_text='Top 12 IT Positions Salary Comparison between H1B and National In 2019')

fig.show()
# Out:
# <div>                            <div id="411d6540-0906-4f71-9882-56ad423eba13" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("411d6540-0906-4f71-9882-56ad423eba13")) {                    Plotly.newPlot(                        "411d6540-0906-4f71-9882-56ad423eba13",                        [{"name": "H1B Avg Salary", "type": "bar", "x": ["COMPUTER AND INFORMATION RESEARCH SCIENTISTS", "COMPUTER SYSTEMS ANALYSTS", "INFORMATION SECURITY ANALYSTS", "COMPUTER PROGRAMMERS", "SOFTWARE DEVELOPERS, APPLICATIONS", "SOFTWARE DEVELOPERS, SYSTEMS SOFTWARE", "DATABASE ADMINISTRATORS", "NETWORK AND COMPUTER SYSTEMS ADMINISTRATORS", "COMPUTER NETWORK ARCHITECTS", "COMPUTER OCCUPATIONS, ALL OTHER", "OPERATIONS RESEARCH ANALYSTS", "STATISTICIANS"], "y": [112769.41313976378, 85730.6491753951, 92045.17970308, 74083.98076173145, 97035.00886510737, 108835.09461878301, 84315.00135375494, 82722.83506686479, 99103.18857561333, 82815.68857556312, 79970.30741446998, 86239.80907941615]}, {"name": "National Avg Salary", "type": "bar", "x": ["COMPUTER AND INFORMATION RESEARCH SCIENTISTS", "COMPUTER SYSTEMS ANALYSTS", "INFORMATION SECURITY ANALYSTS", "COMPUTER PROGRAMMERS", "SOFTWARE DEVELOPERS, APPLICATIONS", "SOFTWARE DEVELOPERS, SYSTEMS SOFTWARE", "DATABASE ADMINISTRATORS", "NETWORK AND COMPUTER SYSTEMS ADMINISTRATORS", "COMPUTER NETWORK ARCHITECTS", "COMPUTER OCCUPATIONS, ALL OTHER", "OPERATIONS RESEARCH ANALYSTS", "STATISTICIANS"], "y": [127460, 96160, 104210, 92610, 106980, 111620, 96110, 88410, 115110, 92410, 90600, 95680]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333 ...

# %% [markdown]
# ### Percentage by Case Status

# %%
labels = ['Certified','Certified-Withdrawn','Denied','Withdrawn']
fig = make_subplots(rows=1, cols=2, specs=[[{'type':'domain'}, {'type':'domain'}]])
fig.add_trace(go.Pie(labels=labels,values=[90,6,1,3],name='IT Jobs'),
             1,1)

fig.add_trace(go.Pie(labels=['IT','Non-IT'],values=[48,52],name='Deneid'),
                    1,2)

fig.update_layout(
        title_text = "Case Status Rates",
        annotations=[dict(text='IT Jobs', x=0.18, y=0.5, font_size=19, showarrow=False),
                 dict(text='Deneid Rate', x=0.87, y=0.5, font_size=19, showarrow=False)])

fig.update_traces(hole=.5,hoverinfo='label+percent+name')

fig.show()
# Out:
# <div>                            <div id="85c38dc6-67e8-4234-bf71-db20576c335b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85c38dc6-67e8-4234-bf71-db20576c335b")) {                    Plotly.newPlot(                        "85c38dc6-67e8-4234-bf71-db20576c335b",                        [{"domain": {"x": [0.0, 0.45], "y": [0.0, 1.0]}, "hole": 0.5, "hoverinfo": "label+percent+name", "labels": ["Certified", "Certified-Withdrawn", "Denied", "Withdrawn"], "name": "IT Jobs", "type": "pie", "values": [90, 6, 1, 3]}, {"domain": {"x": [0.55, 1.0], "y": [0.0, 1.0]}, "hole": 0.5, "hoverinfo": "label+percent+name", "labels": ["IT", "Non-IT"], "name": "Deneid", "type": "pie", "values": [48, 52]}],                        {"annotations": [{"font": {"size": 19}, "showarrow": false, "text": "IT Jobs", "x": 0.18, "y": 0.5}, {"font": {"size": 19}, "showarrow": false, "text": "Deneid Rate", "x": 0.87, "y": 0.5}], "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcont ...

# %% [markdown]
# ### What may casuses H1B deneid?

# %% [markdown]
# #### A. Denied H1B by Salary and Job titles

# %%
job = deny['SOC_TITLE']
wage = deny['PREVAILING_WAGE_1']
fig = px.scatter(deny,x=job,y=wage,
                color=job
                )
fig.update_xaxes(showticklabels=False)
fig.update_layout(title_text='Denied H1B by IT Positions and Salaries',
                 xaxis_title=  'IT Positions',
                 yaxis_title='Salary')
fig.show()
# Out:
# <div>                            <div id="c742b7fa-c8cb-4690-9ae3-b6b4c71d901f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c742b7fa-c8cb-4690-9ae3-b6b4c71d901f")) {                    Plotly.newPlot(                        "c742b7fa-c8cb-4690-9ae3-b6b4c71d901f",                        [{"hovertemplate": "SOC_TITLE=%{x}<br>PREVAILING_WAGE_1=%{y}<extra></extra>", "legendgroup": "SOFTWARE DEVELOPER, APPLICATIONS", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "SOFTWARE DEVELOPER, APPLICATIONS", "showlegend": true, "type": "scattergl", "x": ["SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE DEVELOPER, APPLICATIONS", "SOFTWARE D ...

# %% [markdown]
# #### B. 5 numbers comparison between Certified and Denied H1B (IT Jobs FULL TIME ONLY)

# %%
fig = px.box(Box,x='STATUS',y='PREVAILING_WAGE_1',color='STATUS')

fig.update_layout(title_text='5 numbers comparison of Certified & Denied Full Time H1B visa (IT ONLY)',
                  yaxis_title=  'SALARY')
fig.show()
# Out:
# <div>                            <div id="1335164e-86d7-4399-b14f-8facf3f71746" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1335164e-86d7-4399-b14f-8facf3f71746")) {                    Plotly.newPlot(                        "1335164e-86d7-4399-b14f-8facf3f71746",                        [{"alignmentgroup": "True", "hovertemplate": "STATUS=%{x}<br>PREVAILING_WAGE_1=%{y}<extra></extra>", "legendgroup": "CERTIFIED", "marker": {"color": "#636efa"}, "name": "CERTIFIED", "notched": false, "offsetgroup": "CERTIFIED", "orientation": "v", "showlegend": true, "type": "box", "x": ["CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIED", "CERTIFIE ...

# %% [markdown]
# ### The company pays least but with highest certified rate

# %%
fig = px.scatter(combined1,x='Certified_Rate',
                y='Avg Salary',
                size='Avg Salary',
                color='Normalized_Name')
fig.update_layout(title_text='Top10 Sponsors - Certified Rate vs Avg Salary')
fig.show()
# Out:
# <div>                            <div id="3b9bf8b0-478d-44de-8d0c-38727b7b897d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b9bf8b0-478d-44de-8d0c-38727b7b897d")) {                    Plotly.newPlot(                        "3b9bf8b0-478d-44de-8d0c-38727b7b897d",                        [{"hovertemplate": "Normalized_Name=ACCENTURE<br>Certified_Rate=%{x}<br>Avg Salary=%{marker.size}<extra></extra>", "legendgroup": "ACCENTURE", "marker": {"color": "#636efa", "size": [87719.23], "sizemode": "area", "sizeref": 288.560075, "symbol": "circle"}, "mode": "markers", "name": "ACCENTURE", "orientation": "v", "showlegend": true, "type": "scatter", "x": [97.92], "xaxis": "x", "y": [87719.23], "yaxis": "y"}, {"hovertemplate": "Normalized_Name=AMAZON<br>Certified_Rate=%{x}<br>Avg Salary=%{marker.size}<extra></extra>", "legendgroup": "AMAZON", "marker": {"color": "#EF553B", "size": [99304.57], "sizemode": "area", "sizeref": 288.560075, "symbol": "circle"}, "mode": "markers", "name": "AMAZON", "orientation": "v", "showlegend": true, "type": "scatter", "x": [98.22], "xaxis": "x", "y": [99304.57], "yaxis": "y"}, {"hovertemplate": "Normalized_Name=CAPGEMINI<br>Certified_Rate=%{x}<br>Avg Salary=%{marker.size}<extra></extra>", "legendgroup": "CAPGEMINI", "marker": {"color": "#00cc96", "size": [86421.2], "sizemode": "area", "sizeref": 288.560075, "symbol": "circle"}, "mode": "markers", "name": "CAPGEMINI", "orientation": "v", "showlegend": true, "type": "scatter", "x": [98.44], "xaxis": "x", "y": [86421.2], "yaxis": "y"}, {"hovertemplate": "Normalized_Name=COGNIZANT<br>Certified_Rate=%{x}<br>Avg Salary=%{marker.size}<extra></extra>", "legendgroup": "COGNIZANT", "marker": {"color": "#ab63fa", "size": [86142.18], "sizemode": "area", "sizeref": 288.560075, "symbol": "circle"}, "mode": "markers", "name": "COGNIZANT", "orientation": "v", "showlegend": true, "type": "scatter", "x": [98.96], "xaxis": "x", "y": [86142.18], "yaxis": "y"}, {"hovertemplate": "Normalized_Name=DELOITTE<br>Certified_Rate=%{x}<br>Avg Salary=%{marker.size}<extra></extra>", "legendgroup": "DELOITTE", "marker": {"color": "#FFA15A", "size": [85183.25], "sizemode": "area", "sizeref": 288.560075, "symbol": "circle"}, "mode": "markers", "name": "DELOITTE", "orientation": "v", "showlegend": true, "type": "scatter", "x": [98.54], "xaxis": "x", "y": [85183.25], "yaxis": "y"}, {"hovertemplate": "Normalized_Name=GOOGLE<br>Certified_Rate=%{x}<br>Avg Salary=%{marker.size}<extra></extra>", "legendgroup": "GOOGLE", "marker": {"color": "#19d3f3", "size": [115424.03], "sizemode": "area", "sizeref": 288.560075, "symbol": "circle"}, "mode": "markers", "name": "GOOGLE", "orientation": "v", "showlegend": true, "type": "scatter", "x": [95.28], "xaxis": "x", "y": [115424.03], "yaxis": "y"}, {"hovertemplate": "Normalized_Name=IBM<br>Certified_Rate=%{x}<br>Avg Salary=%{marker.size}<extra></extra>", "legendgroup": "IBM", "marker": {"color": "#FF6692", "size": [89259.83], "sizemode": "area", "sizeref": 288.560075, "symbol": "circle"}, "mode": "markers", "name": "IBM", "orientation": "v", "showlegend": true, "type": "scatter", "x": [84.7], "xaxis": "x", "y": [89259.83], "yaxis": "y"}, {"hovertemplate": "Normalized_Name=INFOSYS<br>Certified_Rate=%{x}<br>Avg Salary=%{marker.size}<extra></extra>", "legendgroup": "INFOSYS", "marker": {"color": "#B6E880", "size": [80728.88], "sizemode": "area", "sizeref": 288.560075, "symbol": "circle"}, "mode": "markers", "name": "INFOSYS", "orientation": "v", "showlegend": true, "type": "scatter", "x": [99.94], "xaxis": "x", "y": [80728.88], "yaxis": "y"}, {"hovertemplate": "Normalized_Name=MICROSOFT <br>Certified_Rate=%{x}<br>Avg Salary=%{marker.size}<extra></extra>", "legendgroup": "MICROSOFT ", "marker": {"color": "#FF97FF", "size": [114 ...

# %% [markdown]
# ### Does salary impacts certified rate? (IT Jobs ONLY)

# %%
g=d['Count of Ceritified Cases']
u=d['Salary']
fig = go.Figure(data=go.Scatter(x=u,
                            y=g,
                            mode='markers'))
fig.update_layout(title_text='Does salary impacts certified rate?',
                 yaxis_title=  'Number of Certified H1B',
                 xaxis_title ='Salary')
fig.show()
# Out:
# <div>                            <div id="5d64ec4a-21f3-49fe-983e-b9c6516b821a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d64ec4a-21f3-49fe-983e-b9c6516b821a")) {                    Plotly.newPlot(                        "5d64ec4a-21f3-49fe-983e-b9c6516b821a",                        [{"mode": "markers", "type": "scatter", "x": [18699.0, 19594.0, 24544.0, 25542.0, 32766.0, 34403.0, 34819.0, 35006.0, 35152.0, 35339.0, 35485.0, 35672.0, 35797.0, 36213.0, 37669.0, 38334.0, 38626.0, 38709.0, 39478.0, 39749.0, 40539.0, 40622.0, 40706.0, 40872.0, 41454.0, 42078.0, 42266.0, 42328.0, 42432.0, 42848.0, 43181.0, 43243.0, 43285.0, 43347.0, 43451.0, 43763.0, 43805.0, 43846.0, 44096.0, 44158.0, 44179.0, 44283.0, 44304.0, 44450.0, 44486.4, 44741.0, 44762.0, 44782.0, 44949.0, 45074.0, 45136.0, 45282.0, 45344.0, 45448.0, 45531.0, 45594.0, 45802.0, 45843.0, 46030.0, 46051.0, 46093.0, 46155.0, 46176.0, 46218.0, 46259.0, 46280.0, 46405.0, 46426.0, 46488.0, 46509.0, 46592.0, 46634.0, 46654.0, 46675.2, 46925.0, 46966.0, 46987.0, 47362.0, 47549.0, 47570.0, 47611.0, 47673.6, 47736.0, 47965.0, 48000.0, 48048.0, 48069.0, 48090.0, 48131.0, 48172.8, 48194.0, 48298.0, 48402.0, 48485.0, 48506.0, 48526.0, 48547.0, 48610.0, 48651.0, 48693.0, 48714.0, 48734.0, 48755.0, 49067.0, 49088.0, 49190.4, 49192.0, 49213.0, 49234.0, 49296.0, 49324.8, 49358.0, 49379.0, 49400.0, 49462.0, 49483.0, 49516.799999999996, 49587.0, 49650.0, 49712.0, 49816.0, 49858.0, 49878.0, 49962.0, 50024.0, 50066.0, 50086.0, 50107.0, 50170.0, 50190.0, 50227.2, 50336.0, 50357.0, 50398.0, 50553.6, 50648.0, 50794.0, 50814.0, 50939.0, 51002.0, 51064.0, 51085.0, 51126.0, 51168.0, 51206.4, 51293.0, 51355.0, 51438.0, 51563.0, 51584.0, 51646.0, 51730.0, 51792.0, 51854.0, 51955.2, 51958.0, 51974.4, 51979.0, 52000.0, 52042.0, 52062.0, 52104.0, 52166.0, 52187.0, 52229.0, 52312.0, 52354.0, 52395.0, 52437.0, 52582.0, 52624.0, 52645.0, 52707.0, 52728.0, 52811.0, 52838.4, 52853.0, 52894.0, 52936.0, 53019.0, 53040.0, 53061.0, 53088.0, 53102.0, 53123.0, 53165.0, 53186.0, 53290.0, 53337.600000000006, 53352.0, 53394.0, 53414.0, 53435.0, 53456.0, 53477.0, 53498.0, 53560.0, 53602.0, 53622.0, 53643.0, 53664.0, 53706.0, 53726.0, 53747.0, 53789.0, 53893.0, 53914.0, 53934.0, 53976.0, 54059.0, 54163.0, 54267.0, 54288.0, 54309.0, 54330.0, 54371.0, 54413.0, 54432.0, 54434.0, 54475.0, 54496.0, 54517.0, 54579.0, 54642.0, 54643.200000000004, 54681.6, 54725.0, 54746.0, 54850.0, 54870.0, 54912.0, 54933.0, 54954.0, 54969.6, 54974.0, 54995.0, 55037.0, 55078.0, 55099.0, 55120.0, 55162.0, 55245.0, 55266.0, 55286.0, 55307.0, 55390.0, 55453.0, 55474.0, 55488.0, 55494.0, 55515.0, 55536.0, 55661.0, 55702.0, 55723.0, 55724.0, 55744.0, 55795.2, 55852.8, 55869.0, 55890.0, 55931.0, 55952.0, 55973.0, 55994.0, 56014.0, 56035.0, 56077.0, 56098.0, 56160.0, 56179.200000000004, 56181.0, 56243.0, 56264.0, 56306.0, 56347.0, 56352.0, 56368.0, 56402.0, 56406.0, 56409.6, 56472.0, 56514.0, 56534.0, 56544.0, 56638.0, 56659.200000000004, 56678.4, 56742.0, 56805.0, 56810.0, 56811.0, 56812.8, 56826.0, 56870.4, 56909.0, 56950.0, 56992.0, 57013.0, 57034.0, 57054.0, 57062.399999999994, 57075.0, 57081.6, 57096.0, 57117.0, 57120.0, 57200.0, 57221.0, 57242.0, 57262.0, 57304.0, 57312.0, 57325.0, 57366.0, 57387.0, 57450.0, 57456.0, 57470.0, 57491.0, 57512.0, 57533.0, 57542.399999999994, 57574.0, 57616.0, 57637.0, 57658.0, 57678.0, 57753.6, 57762.0, 57771.0, 57782.0, 57803.0, 57824.0, 57845.0, 57866.0, 57868.8, 57886.0, 57907.0, 57907.2, 57928.0, 57949.0, 57990.0, 58011.0, 58022.399999999994, 58053.0, 58074.0, 58094.0, 58115.0, 58157.0, 58178.0, 58198.0, 58219.0, 58240.0, 58261.0, 58282.0, 58302.0, 58310.4, 58323.0, 58344.0, 58368.0, 58386.0, 58406.0, 58448.0, 58469.0, 58531.0, 58552.0, 58579.200000000004, 58614.0, 5862 ...

# %% [markdown]
# # Conclusion
#
# ##### In 2019, more than half of H1B cases filed with IT positions. In the top 30 job titles, IT jobs occupy 12 out of it. The title 'software developers for applications' has more than 200k H1B cases. Based on the map, most IT jobs are located on the East, South, and West coasts. California has the most IT jobs in the States, which has at least 86k. For those 12 IT jobs, Cognizant sponsored more than 25k cases in 2019. In other words, Cognizant applied 50% of the H1B visa in the IT field.  In comparing the number of employments, H1B workers have different impacts on the nation with different positions. But for each IT job, the average salary of H1B workers is lower than the national average. Among all IT jobs, the denied rate of H1B is only 1%, but compared to Non-IT jobs, most rejected cases are from the IT industry. Salary has minor influences on the H1B certified rate. Still, it does not have a linear relationship with the certified rate, which means a high salary does not guarantee to get an H1B visa certified.
